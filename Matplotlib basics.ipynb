# %%
import matplotlib.pyplot as plt

x = [1,3,5]
y = [2,4,6]

plt.plot(x,y)
plt.title('Example')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
import matplotlib.pyplot as plt

x = [1,3,5]
y = [2,4,6]

plt.plot(x,y,'r')
plt.title('Example')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
import matplotlib.pyplot as plt

x = [1,3,5,7]
y = [2,4,6,8]
x1 = [3,6,9,12]
y1 = [4,8,12,16]
plt.plot(x,y,'r')
plt.plot(x1,y1,'g')
plt.title('Example')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
import matplotlib.pyplot as plt

x = [1,3,5,7]
y = [2,4,6,8]
x1 = [3,6,9,12]
y1 = [4,8,12,16]
plt.plot(x,y,'r')
plt.plot(x1,y1,'g')
plt.title('Example')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(['plot1','plot2'])
